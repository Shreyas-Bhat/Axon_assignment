# %% [markdown]
# # part a

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#a
I_A = [0.0015 if (i >=25 and i<65) else 0 for i in range(0,100)]
plt.plot(I_A)
plt.xlabel('Time')
plt.ylabel('current')
# Out:
# Text(0, 0.5, 'current')

# %%
#b
I_B = [0.00075 for i in range(0,100)]
plt.plot(I_B)
plt.xlabel('Time')
plt.ylabel('current')
# Out:
# Text(0, 0.5, 'current')

# %%
#c
I_C = [5*np.sin(75*i) for i in range(0,100)]  
plt.plot(I_C)
plt.xlabel('Time')
plt.ylabel('current')
# Out:
# Text(0, 0.5, 'current')

# %%
#d
I_D = [-2*np.sin(30*i) + 3*np.sin(45*i) + np.cos(60*i) for i in range(0, 100)]
plt.plot(I_D)
plt.xlabel('Time')
plt.ylabel('current')
# Out:
# Text(0, 0.5, 'current')

# %% [markdown]
# # partb

# %%
# f is mean firing rate of neuron
#vth is threshold frequency 
#I_B is dummy current
#delta is absolute refractory period
# R = 2000
# C = 0.005
# F = []
# while(True):


#     i = 0
#     while(R * I_D[i] - vth>0):
#         f = (delta + tau * np.log( ( R * I_D[i] ) / ( R * I_D[i] - vth ) ) )
#         i+=1
#         F.append(f)
#     if(len(F)>10):
#         break
#     else:
#         break
tau = 10 
vth = 20
delta = 5
Is = np.linspace(0,50,51)
try:
    f = 1 / ( delta + tau * np.log( Is / ( Is - vth ) ) )
except Exception:
    pass


plt.xlabel('current')
plt.ylabel('vfiring')
plt.plot(Is,f)
plt.show()
# Out:
# C:\Users\shreyas\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\shreyas\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# C:\Users\shreyas\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in log
